# %% [markdown]
# <a href="https://colab.research.google.com/github/junseokkim93/Git-Tutorial/blob/main/00_TensorFlow_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
